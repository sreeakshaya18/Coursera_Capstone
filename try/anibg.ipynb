# %%
import bs4
import lxml.html
import selenium
import requests
import pandas as pd
import numpy as np
from selenium.common.exceptions import NoSuchElementException
from lxml import etree
from selenium import webdriver
import urllib.request

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\Akshaya\Downloads\chromedriver.exe')

# %%
link = "https://www.google.com/search?q=anime+boy+&tbm=isch&ved=2ahUKEwjW0YOukZjqAhVm_TgGHR5lB98Q2-cCegQIABAA&oq=anime+boy+&gs_lcp=CgNpbWcQA1DBsgFY8LMBYOW4AWgAcAB4AIABAIgBAJIBAJgBAKABAaoBC2d3cy13aXotaW1n&sclient=img&ei=EhDyXtaAKeb64-EPnsqd-A0&bih=838&biw=1707"
driver.get(link)

# %%
i=0
while(True and i<1001):
    try:
        img = driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[1]/div/div/div/div/div[1]/div[1]/div['+str(i)+']/a[1]/div[1]/img')
        src = img.get_attribute('src')
        urllib.request.urlretrieve(src, "boy_" +str(i)+ ".jpg")
        i+=1
    except:
        i+=1
        pass

# %%
link = "https://www.google.com/search?q=anime+girl&sxsrf=ALeKk00NTL-2AcBHZiYjaDgZw79VMbZycA:1592921445318&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiJzZznjpjqAhUNwzgGHXQmBuAQ_AUoAXoECAsQAw"
driver.get(link)

# %%
i=0
while(True and i<1001):
    try:
        img = driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[1]/div/div/div/div/div[1]/div[1]/div['+str(i)+']/a[1]/div[1]/img')
        src = img.get_attribute('src')
        urllib.request.urlretrieve(src, "girl_" +str(i)+ ".jpg")
        i+=1
    except:
        i+=1
        pass
